# %%
#Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler , MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score , mean_squared_error

# %%
dataset = pd.read_csv('Datasets/Levels_Fyi_Salary_Data.csv')
dataset
# Out:
# /Users/Erick/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (37) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             timestamp                 company                         title  \
# 0         8/5/21 8:04            Athenahealth               Product Manager
# 1       12/9/18 10:22               Bloomberg  Software Engineering Manager
# 2         6/7/21 8:21  Bridgewater Associates             Software Engineer
# 3        9/25/20 0:34            Jump Trading             Software Engineer
# 4        5/9/21 13:36    Prudential Financial              Business Analyst
# ...               ...                     ...                           ...
# 62637  12/21/20 14:11                    Zoom             Software Engineer
# 62638    2/8/21 18:48                    Zoom             Software Engineer
# ...

# %%
dataset.describe ()
# Out:
#        totalyearlycompensation  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# count             6.264200e+04         0.0          0.0          0.0
# mean              2.163004e+05         NaN          NaN          NaN
# std               1.380337e+05         NaN          NaN          NaN
# min               1.000000e+04         NaN          NaN          NaN
# 25%               1.350000e+05         NaN          NaN          NaN
# 50%               1.880000e+05         NaN          NaN          NaN
# 75%               2.640000e+05         NaN          NaN          NaN
# max               4.980000e+06         NaN          NaN          NaN
#
#        yearsofexperience  yearsatcompany    basesalary  stockgrantvalue  \
# count       62642.000000    62642.000000  6.264200e+04     6.264200e+04
# mean            7.204135        2.702093  1.366873e+05     5.148608e+04
# std             5.840375        3.263656  6.136928e+04     8.187457e+04
# ...

# %%
ds = pd.read_csv("Datasets/Levels_Fyi_Salary_Data.csv", usecols = ['Salary Level', 'Total Annual Compensation', 'Years at Company', 'Years of Experience'])
ds
# Out:
#      Salary Level  Total Annual Compensation  Years of Experience  \
# 0               1                      40000                    5
# 1               1                      41000                    1
# 2               1                      48000                    0
# 3               1                      50000                    5
# 4               1                      50000                    2
# ..            ...                        ...                  ...
# 490             3                     225000                    8
# 491             3                     210000                    0
# 492             3                     500000                   13
# 493             3                     482000                   21
# 494             3                     400000                   10
#
#      Years at Company
# 0                 2.0
# 1                 1.0
# 2                 0.0
# 3                 0.0
# 4                 1.0
# ..                ...
# ...

# %%
X = ds.drop('Total Annual Compensation',axis=1)
y = ds['Total Annual Compensation']

# %%
X.shape , y.shape
# Out:
# ((495, 3), (495,))

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,y,random_state=495,test_size=0.2)
X_train.shape , X_test.shape , Y_train.shape , Y_test.shape
# Out:
# ((396, 3), (99, 3), (396,), (99,))

# %%
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(X_test)
pred
# Out:
# array([170508.43068486, 161863.97350188, 181295.4804183 , 161588.17275931,
#        185029.06403407, 170784.23142744, 156263.59807823, 161588.17275931,
#        157992.48951483, 161588.17275931, 168779.53924827, 163317.0641959 ,
#        159997.181694  ,  92863.28783871, 188624.74727855,  87538.71315764,
#         80209.44629739, 174242.01430063, 179566.58898171, 163317.0641959 ,
#        181295.4804183 ,  80209.44629739, 156263.59807823, 105930.8304939 ,
#         83943.02991316, 188762.64764984, 172375.22249275, 177975.5979164 ,
#        165183.85600379, 165321.75637507, 125224.43703903, 172651.02323532,
#        170646.33105615,  80209.44629739, 190353.63871515,  96596.87145448,
#         80209.44629739, 174242.01430063, 170646.33105615, 166912.74744038,
#         80209.44629739, 165597.55711765, 167050.64781167,  80209.44629739,
#         91410.19714469, 186757.95547067,  83943.02991316,  85809.82172104,
# ...

# %%
Y_test
# Out:
# 360    130000
# 326    130000
# 246    100000
# 385    165000
# 374    169000
#         ...
# 235    107000
# 75      80000
# 64      85000
# 312    131000
# 209    125000
# Name: Total Annual Compensation, Length: 99, dtype: int64

# %%
diff = Y_test - pred

# %%
pd.DataFrame(np.c_[Y_test , pred , diff] , columns=['Actual','Predicted','Difference'])
# Out:
#       Actual      Predicted    Difference
# 0   130000.0  170508.430685 -40508.430685
# 1   130000.0  161863.973502 -31863.973502
# 2   100000.0  181295.480418 -81295.480418
# 3   165000.0  161588.172759   3411.827241
# 4   169000.0  185029.064034 -16029.064034
# ..       ...            ...           ...
# 94  107000.0  156263.598078 -49263.598078
# 95   80000.0   82076.238105  -2076.238105
# 96   85000.0   83805.129542   1194.870458
# 97  131000.0  214070.330732 -83070.330732
# 98  125000.0  170508.430685 -45508.430685
#
# [99 rows x 3 columns]

# %%
lr.score(X_test , Y_test)
# Out:
# 0.4956648789837693

# %%
lr.score(X_test , Y_test)
# Out:
# 0.4956648789837693

# %%
mean_squared_error(Y_test , pred, squared=False)
# Out:
# 39552.60342480212

# %%
r2_score(Y_test , pred)
# Out:
# 0.4956648789837693
